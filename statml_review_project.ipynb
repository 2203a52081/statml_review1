# %% [markdown]
# # PROFILE

# %% [raw]
# Name:Ch.Chandu
# Section:AIML-A
# subject:statml
# project:wine quality prediction

# %% [markdown]
#    # wine quality prediction

# %% [markdown]
# # importing all the libraries

# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
p= pd.read_csv(r"C:\Users\CHANDU\WineQT.csv")
print("Successfully Imported Data!")
p
# Out:
# ...............DATA SET................
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# ...

# %% [markdown]
# # SHAPE AND DESCRIPTION OF THE DATA SET

# %%
p.shape
# Out:
# (1143, 13)

# %%
p.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %% [markdown]
# # finding Null values

# %%
p.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %% [markdown]
# WE FILL FIND THERE IS NO NULL VALUES IN THE ABOVE DATA SET

# %%
p.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %% [markdown]
# # countplot

# %% [markdown]
# using seaborn library ,implementing plots

# %%
sns.catplot(x='quality', data = p, kind = 'count')

# %%
sns.catplot(x='fixed acidity', data = p, kind = 'count')

# %%
sns.catplot(x='volatile acidity', data = p, kind = 'count')

# %%
sns.catplot(x='citric acid', data = p, kind = 'count')

# %%
sns.catplot(x='residual sugar', data = p, kind = 'count')

# %%
sns.catplot(x='chlorides', data = p, kind = 'count')

# %%
sns.catplot(x='free sulfur dioxide', data = p, kind = 'count')

# %%
sns.catplot(x='total sulfur dioxide', data = p, kind = 'count')

# %%
sns.catplot(x='density', data = p, kind = 'count')

# %%
sns.catplot(x='pH', data = p, kind = 'count')

# %%
sns.histplot(p["alcohol"], kde=True)                                    #kernal destiny estimation
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# # Understanding correlation between the columns using heat map

# %%
b=p.drop("Id",axis=1)
b
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
corr = b.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # SEPARATION OF FEATURES AND TARGET VARIABLE

# %%
b['goodquality'] = [1 if x >= 7 else 0 for x in b['quality']]# Separate feature variables and target variable
x= b.drop(['quality','goodquality'], axis = 1)
y = b['goodquality']
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: goodquality, Length: 1143, dtype: int64

# %%
X = b.drop(['quality', 'goodquality'], axis=1)
Y = b['goodquality']
plt.bar(X.index, Y)
plt.show()

# %% [markdown]
# # Implementing logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=7)
# Initialize and train a logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
# Make predictions on the test set
Y_pred = model.predict(X_test)
# Calculate the accuracy of the model
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.8746355685131195

# %% [markdown]
# # SVM(Support Vector Machine)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.8717201166180758

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
f = x_train.shape[1]
w = []
for _ in range(f):
    weight = rd.random()
    w.append(weight)
bias = rd.random()
def perceptron(x):
    z = (
        x[0] * w[0] +
        x[1] * w[1] +
        x[2] * w[2] +
        x[3] * w[3] +
        x[4] * w[4] +
        x[5] * w[5] +
        x[6] * w[6] +
        x[7] * w[7] +
        x[8] * w[8] +
        x[9] * w[9] +
        x[10] * w[10] +
        x[11] * w[11] +
        x[12] * w[12] +
        bias
    )
    return 1 / (1 + np.exp(-z))
y_p = []
for x in x_train:
    if perceptron(x) >= 0.5:
        y_p.append(1)
    else:
        y_p.append(0)

c_p = np.sum(y_p == y_train)
total = len(y_train)
acc = c_p / total
print(f'Accuracy: {acc:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 10
#       8 w = []
#       9 for _ in range(f):
# ---> 10     weight = rd.random()
#      11     w.append(weight)
#      12 bias = rd.random()
#
# NameError: name 'rd' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
import random as rd

scaler = MinMaxScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
f = x_train.shape[1]
w = []
for _ in range(f):
    weight = rd.random()
    w.append(weight)
bias = rd.random()

def perceptron(x):
    z = sum(xi * wi for xi, wi in zip(x, w)) + bias
    z = (
        x[0] * w[0] +
        x[1] * w[1] +
        x[2] * w[2] +
        x[3] * w[3] +
        x[4] * w[4] +
        x[5] * w[5] +
        x[6] * w[6] +
        x[7] * w[7] +
        x[8] * w[8] +
        x[9] * w[9] +
        x[10] * w[10] +
        x[11] * w[11] +
        x[12] * w[12] +
        bias
    )
    return 1 / (1 + np.exp(-z))
y_p = []
for x in x_train:
    if perceptron(x) >= 0.5:
        y_p.append(1)
    else:
        y_p.append(0)

c_p = np.sum(y_p == y_train)
total = len(y_train)
acc = c_p / total
print(f'Accuracy: {acc:.2f}')# Rest of your code...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 5
#       2 import random as rd
#       4 scaler = MinMaxScaler()
# ----> 5 scaler.fit(x)
#       6 x_scaled = scaler.transform(x)
#       7 x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)
#
# File E:\jupy\Lib\site-packages\sklearn\preprocessing\_data.py:434, in MinMaxScaler.fit(self, X, y)
#     432 # Reset internal state before fitting
#     433 self._reset()
# --> 434 return self.partial_fit(X, y)
#
# File E:\jupy\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# ...
